# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('FormattedFlights.csv')
df.head()
# Out:
#    id  arr_delay                    name
# 0   0         11   United Air Lines Inc.
# 1   1         20   United Air Lines Inc.
# 2   2         33  American Airlines Inc.
# 3   3        -18         JetBlue Airways
# 4   4        -25    Delta Air Lines Inc.

# %% [markdown]
# # Statistical Analysis

# %%
df_stats = df.describe().transpose()
df_stats
# Out:
#               count           mean           std   min      25%       50%  \
# id         214107.0  112275.777733  65401.691810   0.0  55422.5  111636.0
# arr_delay  214107.0       1.387507     28.130393 -60.0    -16.0      -5.0
#
#                 75%       max
# id         168873.5  225951.0
# arr_delay      11.0     120.0

# %%
df[['arr_delay', 'name']].groupby(['name']).describe()
# Out:
#                             arr_delay                                     \
#                                 count       mean        std   min    25%
# name
# AirTran Airways Corporation    2146.0   9.452470  26.769600 -44.0  -8.00
# Alaska Airlines Inc.            462.0  -8.218615  28.740552 -60.0 -27.00
# American Airlines Inc.        21038.0  -3.351792  27.309268 -60.0 -21.00
# Delta Air Lines Inc.          31173.0  -4.211401  24.988558 -60.0 -20.00
# Endeavor Air Inc.             11597.0  -0.298094  30.814356 -60.0 -21.00
# Envoy Air                     16552.0   5.307999  27.790652 -49.0 -13.00
# ExpressJet Airlines Inc.      32764.0   9.484861  32.141646 -58.0 -13.00
# Frontier Airlines Inc.          435.0   8.841379  26.757920 -47.0  -9.00
# Hawaiian Airlines Inc.          221.0 -15.398190  23.841423 -60.0 -31.00
# JetBlue Airways               35124.0   3.375014  27.559555 -60.0 -14.00
# Mesa Airlines Inc.              325.0   5.387692  32.708455 -46.0 -17.00
# ...

# %% [markdown]
# count: the number of fligts by respective air lines .
#
# mean: the average percentage of air delay based upon different air lines
#
# std: the standard deviation of the variable. It indicate that the air delay of AirTran Airways Coopration is generally quite closer to 9.45 minutes where as in Alaska Airline air delay might not be near to its mean ie -8.218 minutes
#
# min: the minimum value of the variable.
#
# 25%: the bottom quartile; represents the lowest 25% of values for the variable, the value between minimum and median .
#
# 50%: the second quartile; represents the lowest 50% of values.
#
# 75%: the top quartile; represents the lowest 75% of values. The trend continues.
#
# max: the maximum value for that variable.

# %%
fig, ax = plt.subplots(figsize=(14,8))

ax.set_ylabel('Airline Names')

# boxplot with only these two variables
_ = df[['arr_delay', 'name']].boxplot(by='name', figsize=(13,8), vert=False, sym='b.', ax=ax)

# %% [markdown]
# Virgin America , United Air Lines inc , US Airways , Southwest Airlines , JetBlue Airways  , ExpressJet Airlines , Envoy , Endeavor , Delta and American Airlines has a number of outliers signified by the blue dots and they tend have outliers above the maximum value point .

# %%
dfair=pd.read_csv('airlines.csv')
dfair.head()
# Out:
#    id  year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   1  2013    1.0  1.0     517.0           515.0        2.0     830.0
# 1   2  2013    1.0  1.0     533.0           529.0        4.0     850.0
# 2   3  2013    1.0  1.0     542.0           540.0        2.0     923.0
# 3   4  2013    1.0  1.0     544.0           545.0       -1.0    1004.0
# 4   5  2013    1.0  1.0     554.0           600.0       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0           819.0       11.0      UA  1545.0  N14228    EWR  IAH     227.0
# 1           830.0       20.0      UA  1714.0  N24211    LGA  IAH     227.0
# 2           850.0       33.0      AA  1141.0  N619AA    JFK  MIA     160.0
# 3          1022.0      -18.0      B6   725.0  N804JB    JFK  BQN     183.0
# 4           837.0      -25.0      DL   461.0  N668DN    LGA  ATL     116.0
#
#    distance  hour  minute             time_hour
# ...

# %%
dfair.describe()
# Out:
#                  id          year         month           day      dep_time  \
# count  83907.000000  83907.000000  83906.000000  83906.000000  82916.000000
# mean   41954.000000   2012.978405      7.446214     15.624675   1342.275833
# std    24222.008856      6.255458      4.461799      8.898955    475.814309
# min        1.000000    201.000000      1.000000      1.000000      1.000000
# 25%    20977.500000   2013.000000      1.000000      8.000000    906.000000
# 50%    41954.000000   2013.000000     10.000000     16.000000   1355.000000
# 75%    62930.500000   2013.000000     11.000000     23.000000   1732.000000
# max    83907.000000   2013.000000     12.000000     31.000000   2400.000000
#
#        sched_dep_time     dep_delay      arr_time  sched_arr_time  \
# count    83906.000000  82916.000000  82870.000000    83906.000000
# mean      1338.087836      7.191736   1520.831628     1542.633518
# std        463.076641     31.461579    508.662746      484.750785
# ...

# %%
plt.hist(df['arr_delay'], color = 'blue', edgecolor = 'black',
         bins = int(180/5))
plt.title('Histogram of Arrival Delays')
plt.xlabel('Delay (min)')
plt.ylabel('Flights')
plt.show()

# %% [markdown]
# For the plot calls, we specify the binwidth by the number of bins. For this plot, I will use bins that are 5 minutes in length, which means that the number of bins will be the range of the data (from -60 to 120 minutes) divided by the binwidth, 5 minutes ( bins = int(180/5))

# %%
# Density Plot and Histogram of all arrival delays
sns.distplot(df['arr_delay'], hist=True, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
plt.title('Histogram with Binwidth = %d' % binwidth, size = 10)
plt.xlabel('Delay (min)', size = 12)
plt.ylabel('Flights', size= 12)
# Out:
# Text(0,0.5,'Flights')

# %%
# Show 4 different binwidths
for i, binwidth in enumerate([1, 5, 10, 15]):
    
    # Set up the plot
    ax = plt.subplot(2, 2, i + 1)
    
    # Draw the plot
    ax.hist(df['arr_delay'], bins = int(180/binwidth),
             color = 'blue', edgecolor = 'black')
    
    # Title and labels
    ax.set_title('Histogram with Binwidth = %d' % binwidth, size = 10)
    ax.set_xlabel('Delay (min)', size = 12)
    ax.set_ylabel('Flights', size= 12)

plt.tight_layout()
plt.show()

# %%
Delay = df['arr_delay']
Delay.describe()
# Out:
# count    214107.000000
# mean          1.387507
# std          28.130393
# min         -60.000000
# 25%         -16.000000
# 50%          -5.000000
# 75%          11.000000
# max         120.000000
# Name: arr_delay, dtype: float64

# %%
x1 = list(df[df['name'] == 'United Air Lines Inc.']['arr_delay'])
x2 = list(df[df['name'] == 'JetBlue Airways']['arr_delay'])
x3 = list(df[df['name'] == 'ExpressJet Airlines Inc.']['arr_delay'])
x4 = list(df[df['name'] == 'Delta Air Lines Inc.']['arr_delay'])
x5 = list(df[df['name'] == 'American Airlines Inc.']['arr_delay'])

# Assign colors for each airline and the names
colors = ['#E69F00', '#56B4E9', '#F0E442', '#009E73', '#D55E00']
names = ['United Air Lines Inc.', 'JetBlue Airways', 'ExpressJet Airlines Inc.','Delta Air Lines Inc.', 'American Airlines Inc.']
         
# Make the histogram using a list of lists
# Normalize the flights and assign colors and names
plt.hist([x1, x2, x3, x4, x5], bins = int(180/15), normed=True,
         color = colors, label=names,stacked=True)

# Plot formatting
plt.legend()
plt.xlabel('Delay (min)')
plt.ylabel('Normalized Flights')
plt.title('Side-by-Side Histogram with Multiple Airlines')
plt.show()

# %% [markdown]
# Satcked = True
# Well, that definitely is not any better! Here, each airline is represented as a section of the whole for each bin, but it’s nearly impossible to make comparisons. For example, at a delay of -15 to 0 minutes, does United Air Lines or JetBlue Airlines have a larger size of the bar? I can’t tell and viewers won’t be able to either. I generally am not a proponent of stacked bars because they can be difficult to interpret (although there are use cases such as when visualizing proportions). Both of the solutions we tried using histograms were not successful, and so it’s time to move to the density plot.

# %%
plt.hist([x1, x2, x3, x4, x5], bins = int(180/15), normed=True,
         color = colors, label=names,stacked=False)

# Plot formatting
plt.legend()
plt.xlabel('Delay (min)')
plt.ylabel('Normalized Flights')
plt.title('Side-by-Side Histogram with Multiple Airlines')
plt.show()

# %% [markdown]
# Stacked = False
# By default, if we pass in a list of lists, matplotlib will put the bars side-by-side. Here, I have changed the binwidth to 15 minutes because otherwise the plot is too cluttered, but even with this modification, this is not an effective figure. There is too much information to process at once, the bars don’t align with the labels, and it’s still hard to compare distributions between airlines. When we make a plot, we want it to be as easy for the viewer to understand as possible, and this figure fails by that criteria! Let’s look at a second potential solution.

# %%
# List of five airlines to plot
airlines = ['United Air Lines Inc.', 'JetBlue Airways', 'ExpressJet Airlines Inc.','Delta Air Lines Inc.', 'American Airlines Inc.']

# Iterate through the five airlines
for airline in airlines:
    # Subset to the airline
    subset = df[df['name'] == airline]
    
    # Draw the density plot
    sns.distplot(subset['arr_delay'], hist = False, kde = True,
                 kde_kws = {'linewidth': 3},
                 label = airline)
    
# Plot formatting
plt.legend(prop={'size': 10},title = 'Airline')
plt.title('Density Plot with Multiple Airlines')
plt.xlabel('Delay (min)')
plt.ylabel('Density')
# Out:
# Text(0,0.5,'Density')

# %% [markdown]
# From The above observational trends we surely are able to get the general minimum or avergae delay and we require to calu=culate or choose best possible air line depending on its mean std variance and curve

# %%
# List of five airlines to plot
airlines = ['Endeavor Air Inc.', 'US Airways Inc.', 'United Air Lines Inc.']

# Iterate through the five airlines
for airline in airlines:
    # Subset to the airline
    subset = df[df['name'] == airline]
    
    # Draw the density plot
    sns.distplot(subset['arr_delay'], hist = False, kde = True,
                 kde_kws = {'linewidth': 2},
                 label = airline)
    
# Plot formatting
plt.legend(prop={'size': 10},title = 'Airline')
plt.title('Density Plot with Selected Airlines')
plt.xlabel('Delay (min)')
plt.ylabel('Density')
# Out:
# Text(0,0.5,'Density')

# %% [markdown]
# Endeavor Air Inc ,  US Airways Inc. ,  United Air Lines Inc.
# All have a mean of delay close to zero however US Airways Inc have a low standard deviation which proves that depression of a given point from a mean would be less hence more ofter than not you will be landing a sverage delay time close to mean which is effectively pretty close to zero
